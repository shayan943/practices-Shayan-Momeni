# %%
first_name = input("First name:")
email_address = input("Email:")
phone_number = input("Phone:")
massage = input("Massage:")
msg_text = """Dear NAME ,thank you for reaching out to our company.
we appreciate your interest and are exited to explor how we can support your needs. """
msg_text = msg_text.replace("NAME", first_name)
print(msg_text)
# Out:
# First name: Alex
# Email: karen.ignaci5656@yahoo.com
# Phone: 2386690554
# Massage: no idea
# Dear Alex ,thank you for reaching out to our company.
# we appreciate your interest and are exited to explor how we can support your needs.
