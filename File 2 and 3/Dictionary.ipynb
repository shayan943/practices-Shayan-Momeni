# %%
main_students = {
        "first_name": "Ali",
        "last_name": "Rezaei",
        "student_code": "S12345",
        "date_of_birth": 1998,
        "age": 25,
        "desired_movie": "Inception",
        "desired_song": "Queen",
        "major": "Computer Engineering",
        "academic_level": "Msater",
        "entry_year": 2018,
        "gpa": 17.5,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "career_goal": "Software Developer",
        "strengths": ["Teamwork", "Problem-solving"],
        "weaknesses": ["Public speaking"],
        "favorite_book": "The Alchemist",
        "skills": ["Python", "C++"],
        "languages": ["English", "French"],
        "volunteer_experience": ["Teaching assistant"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}
main_students
# Out:
# {'first_name': 'Ali',
#  'last_name': 'Rezaei',
#  'student_code': 'S12345',
#  'date_of_birth': 1998,
#  'age': 25,
#  'desired_movie': 'Inception',
#  'desired_song': 'Queen',
#  'major': 'Computer Engineering',
#  'academic_level': 'Msater',
#  'entry_year': 2018,
#  'gpa': 17.5,
#  'favorite_courses': ['Algorithms', 'Data Structures'],
#  'hobbies': ['Reading', 'Football'],
#  'career_goal': 'Software Developer',
#  'strengths': ['Teamwork', 'Problem-solving'],
#  'weaknesses': ['Public speaking'],
#  'favorite_book': 'The Alchemist',
#  'skills': ['Python', 'C++'],
#  'languages': ['English', 'French'],
#  'volunteer_experience': ['Teaching assistant'],
#  'feedback': {'courses': 'Challenging but rewarding',
#   'professors': 'Supportive and knowledgeable'}}

# %%
student_1 = {
        "first_name": "Hossein",
        "last_name": "Sadeghi",
        "student_code": "1985656523",
        "date_of_birth": 2000,
        "desired_movie": "Inception",
        "major": "Computer Engineering",
        "academic_level": "Phd",
        "gpa": 19,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}
student_1
# Out:
# {'first_name': 'Hossein',
#  'last_name': 'Sadeghi',
#  'student_code': '1985656523',
#  'date_of_birth': 2000,
#  'desired_movie': 'Inception',
#  'major': 'Computer Engineering',
#  'academic_level': 'Phd',
#  'gpa': 19,
#  'favorite_courses': ['Algorithms', 'Data Structures'],
#  'hobbies': ['Reading', 'Football'],
#  'feedback': {'courses': 'Challenging but rewarding',
#   'professors': 'Supportive and knowledgeable'}}
